# %%
from scoresbibm.utils.data_utils import query, get_summary_df, load_model
from scoresbibm.utils.plot import plot_metric_by_num_simulations, use_style,multi_plot

from scoresbibm.tasks import get_task

import matplotlib.pyplot as plt

import jax 
import jax.numpy as jnp
import numpy as np
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
jax.devices()
# Out:
# [cuda(id=0)]

# %%
PATH = "../../../results/bm_additional"

# %%
DEFAULT_COLORS = {"npe": "#154c79", "nle": "#1e81b0", "nre": "#76b5c5", "nspe": "#fdae61", "score_transformer": "#d73027", "score_transformer_posterior": "#8b27d7", "score_transformer_directed": "#f25d1d","score_transformer_min_graphical": "#f25d1d", "score_transformer_undirected": "#911c1c", "score_transformer_graphical": "#911c1c"}
figsize_per_row = 1.55
figsize_per_col = 1.85

# %%
with use_style("pyloric"):
    fig, axes = multi_plot(PATH, "task", "metric", plot_metric_by_num_simulations, hue="method", color_map=DEFAULT_COLORS, figsize_per_row=2.05, metric=["nll_posterior", "nll_likelihood"], figsize_per_col=2.5, legend_ncol=4, method=["npe", "nle", "score_transformer", "score_transformer_undirected", "score_transformer_directed"],value_statistic="mean",method_sde_name="vesde")
    axes[0,0].set_ylabel("NLL (likelihood)")
    axes[1,0].set_ylabel("NLL (posterior)")
    fig.savefig("nll_posterior.svg", bbox_inches="tight")
    plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...
