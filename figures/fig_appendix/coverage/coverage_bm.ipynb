# %%
from scoresbibm.utils.data_utils import query, get_summary_df, load_model
from scoresbibm.utils.plot import plot_metric_by_num_simulations, use_style,multi_plot, plot_expected_coverage

from scoresbibm.tasks import get_task

import matplotlib.pyplot as plt

import jax 
import jax.numpy as jnp
import numpy as np

from sbi.analysis import pairplot
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
PATH = "../../../results/bm_additional"

# %%
df = query(PATH, task="slcp", method=["score_transformer"], metric=["cov_posterior", "cov_likelihood"], num_simulations=1000)

# %%
df
# Out:
#                method  task  num_simulations  seed  model_id          metric  \
# 85  score_transformer  slcp             1000     0        27  cov_likelihood
# 87  score_transformer  slcp             1000     0        27   cov_posterior
#
#        value  time_train  time_eval  \
# 85  0.510976  114.753767        NaN
# 87  0.571625  114.753767        NaN
#
#                                                   cfg
# 85  {'name': 'bm_additional', 'seed': 0, 'model_id...
# 87  {'name': 'bm_additional', 'seed': 0, 'model_id...

# %%
plot_expected_coverage(PATH,  task="slcp", method="score_transformer",  metric=["cov_posterior", "cov_likelihood"],num_simulations=1000)
plt.show()

# %%
with use_style("pyloric"):
    fig, axes = multi_plot(PATH, "task", "num_simulations", plot_expected_coverage, method=["npe"], metric=["cov_posterior"], figsize_per_col=1.8, figsize_per_row=1.5)
    fig.legend(["posterior"], loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=2)
    fig.suptitle("NPE: Expected Coverage", y=1.05)
    fig.text(-0.02, 0.5, 'Number of simulations', va='center', rotation='vertical')
    fig.savefig("npe_nle_expected_coverage.svg", bbox_inches='tight')
    fig.savefig("npe_nle_expected_coverage.pdf", bbox_inches='tight')
    fig.savefig("npe_nle_expected_coverage.png", bbox_inches='tight')
    plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...

# %%
with use_style("pyloric"):
    fig, axes = multi_plot(PATH, "task", "num_simulations", plot_expected_coverage, method="score_transformer", metric=["cov_posterior", "cov_likelihood"], figsize_per_col=1.8, figsize_per_row=1.5)
    fig.legend(["posterior", "likelihood"], loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=2)
    fig.suptitle("Simformer: Expected Coverage", y=1.05)
    fig.text(-0.02, 0.5, 'Number of simulations', va='center', rotation='vertical')
    fig.savefig("simformer_expected_coverage.svg", bbox_inches='tight')
    fig.savefig("simformer_expected_coverage.pdf", bbox_inches='tight')
    fig.savefig("simformer_expected_coverage.png", bbox_inches='tight')
    plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...

# %%
with use_style("pyloric"):
    fig, axes = multi_plot(PATH, "task", "num_simulations", plot_expected_coverage, method="score_transformer_undirected", metric=["cov_posterior", "cov_likelihood"], figsize_per_col=1.8, figsize_per_row=1.5)
    fig.legend(["posterior", "likelihood"], loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=2)
    fig.suptitle("Simformer (undirected): Expected Coverage", y=1.05)
    fig.text(-0.02, 0.5, 'Number of simulations', va='center', rotation='vertical')
    fig.savefig("simformer_undirected_expected_coverage.svg", bbox_inches='tight')
    fig.savefig("simformer_undirected_expected_coverage.pdf", bbox_inches='tight')
    fig.savefig("simformer_undirected_expected_coverage.png", bbox_inches='tight')
    plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...

# %%
with use_style("pyloric"):
    fig, axes = multi_plot(PATH, "task", "num_simulations", plot_expected_coverage, method="score_transformer_directed", metric=["cov_posterior", "cov_likelihood"], figsize_per_col=1.8, figsize_per_row=1.5)
    fig.legend(["posterior", "likelihood"], loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=2)
    fig.suptitle("Simformer (directed): Expected Coverage", y=1.05)
    fig.text(-0.02, 0.5, 'Number of simulations', va='center', rotation='vertical')
    fig.savefig("simformer_directed_expected_coverage.svg", bbox_inches='tight')
    fig.savefig("simformer_directed_expected_coverage.pdf", bbox_inches='tight')
    fig.savefig("simformer_directed_expected_coverage.png", bbox_inches='tight')
    plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...

# %%
with use_style("pyloric"):
    fig, axes = multi_plot(PATH, "task", "num_simulations", plot_expected_coverage, method="score_transformer_directed", metric=["cov_posterior", "cov_likelihood"], figsize_per_col=1.8, figsize_per_row=1.5)
    fig.legend(["posterior", "likelihood"], loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=2)
    fig.suptitle("Simformer (directed): Expected Coverage", y=1.05)
    fig.text(-0.02, 0.5, 'Number of simulations', va='center', rotation='vertical')
    plt.show()
    fig.savefig("simformer_expected_coverage.svg", bbox_inches='tight')
    fig.savefig("simformer_expected_coverage.png", bbox_inches='tight')
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...

# %%
model = load_model(PATH,36)

# %%
task_name = model.edge_mask_fn_params.get("task")

# %%
task = get_task(task_name)
node_id = task.get_node_id()
condition_mask = jnp.array([True] * task.get_theta_dim() + [False] * task.get_x_dim())

# %%
data = task.get_data(1000, rng=jax.random.PRNGKey(0))

# %%
thetas = data['theta']
xs = data['x']

# %%
log_prob = model.log_prob_batched(thetas, xs, condition_mask=~condition_mask)

# %%
-jnp.mean(log_prob)
# Out:
# Array(4.826, dtype=float32)

# %%
pairplot(np.array(samples))
# Out:
# (<Figure size 1000x1000 with 25 Axes>,
#  array([[<Axes: xlabel='dim 1'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: xlabel='dim 2'>, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: xlabel='dim 3'>, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: xlabel='dim 4'>, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: xlabel='dim 5'>]],
#        dtype=object))
